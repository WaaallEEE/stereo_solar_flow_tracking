# %%
import sys, os
from pathlib import Path
sys.path.append(Path(os.environ['DEV'], 'sunflower').as_posix())
sys.path.append(Path(os.environ['DEV'], 'sunflower', 'cython_modules').as_posix())
sys.path.append(Path(os.environ['DEV'], 'sunflower', 'balltracking').as_posix())

import glob
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as colors
from astropy.io.fits import getheader
from balltracking import mballtrack as mblt
from skimage.feature import peak_local_max
# from cython_modules import interp

plt.rcParams.update({'font.size': 12})
dpi = 168

DTYPE = np.float32
def prep_data(image):
    image2 =np.abs(image)
    image3 = image2.max() - image2
    surface = (image3 - image3.mean())/image3.std()
    return surface.copy(order='C').astype(DTYPE)

# %matplotlib widget

# %%
from cython_modules import interp as cinterp

# %%
# Data prepped by COR2_tracking_prep.ipynb
datadir = Path(os.environ['DATA'], 'STEREO', 'L7tum', 'prep_fits')
fig_dir = Path(datadir, 'figures')
datafiles = sorted(Path(datadir).glob('*.fits'))
nfiles = len(datafiles)
nsamples = 80
roi = np.s_[0:659, 0:600]

# %%
datafiles
# Out:
# [PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0000.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0001.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0002.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0003.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0004.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0005.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0006.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0007.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0008.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0009.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0010.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0011.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0012.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0013.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0014.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0015.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0016.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0017.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0018.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0019.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0020.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0021.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0022.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0023.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0024.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0025.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0026.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0027.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0028.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0029.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0030.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0031.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0032.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0033.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0034.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0035.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0036.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0037.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0038.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0039.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0040.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0041.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0042.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0043.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0044.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0045.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0046.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0047.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0048.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0049.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0050.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0051.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0052.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0053.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0054.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0055.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0056.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0057.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0058.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0059.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0060.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0061.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0062.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0063.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0064.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0065.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0066.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0067.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0068.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0069.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0070.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0071.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0072.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0073.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0074.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0075.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0076.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0077.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0078.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0079.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0080.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0081.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0082.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0083.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0084.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0085.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0086.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0087.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0088.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0089.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0090.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0091.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0092.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0093.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0094.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0095.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0096.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0097.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0098.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0099.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0100.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0101.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0102.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0103.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0104.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0105.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0106.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0107.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0108.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0109.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0110.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0111.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0112.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0113.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0114.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0115.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0116.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0117.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0118.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0119.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0120.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0121.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0122.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0123.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0124.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0125.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0126.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0127.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0128.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0129.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0130.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0131.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0132.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0133.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0134.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0135.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0136.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0137.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0138.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0139.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0140.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0141.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0142.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0143.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0144.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0145.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0146.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0147.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0148.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0149.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0150.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0151.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0152.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0153.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0154.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0155.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0156.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0157.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0158.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0159.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0160.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0161.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0162.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0163.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0164.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0165.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0166.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0167.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0168.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0169.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0170.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0171.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0172.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0173.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0174.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0175.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0176.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0177.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0178.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0179.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0180.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0181.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0182.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0183.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0184.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0185.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0186.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0187.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0188.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0189.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0190.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0191.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0192.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0193.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0194.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0195.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0196.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0197.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0198.fits'),
#  PosixPath('/mnt/c/Data/STEREO/L7tum/prep_fits/prep_0199.fits')]

# %%
plt.close('all')
mbt_dict = {"nt":80,
            "rs":4,
            "am":1,
            "dp":0.3,
            "tdx":1,
            "tdy":100,
            "zdamping":1,
            "ballspacing":15,
            "intsteps":20,
            "mag_thresh":3.5,
            "noise_level":2,
            "track_emergence":False,
            "prep_function":prep_data,
            "datafiles":datafiles,
            "roi":roi,
            "do_plots":False,
            "astropy":True,
            "verbose":False,
            "fig_dir":Path(datadir, 'figures')}

# mbt_p, mbt_n = mblt.mballtrack_main(**mbt_dict)

mbt = mblt.MBT(polarity=1, **mbt_dict)


fig, axs = plt.subplots(ncols=1, nrows=1, figsize=(8,5))
im = axs.imshow(mbt.surface, vmin = -2, vmax=0, origin='lower', cmap='Greys_r')
# position for the colorbar
divider = make_axes_locatable(axs)
cax = divider.append_axes('right', size='1%', pad=0.3)
# Adding the colorbar
cbar = plt.colorbar(im, cax = cax)

axs.plot(mbt.xstart, mbt.ystart, 'r+')
labels = np.arange(0, mbt.nballs)
labels_str = [str(l) for l in labels]
for i, l in enumerate(labels_str):
    axs.text(mbt.xstart[i]+5, mbt.ystart[i], l, color='black', fontsize=10, bbox=dict(facecolor='yellow', alpha=0.4, edgecolor='none', pad=1))

plt.tight_layout()
# bmask = mbt.ystart <= 300
# axs.plot(mbt.xstart[bmask], mbt.ystart[bmask], 'co', ms=10, markerfacecolor='none')
# Out:
# nballs_max = 197700
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
select_balls = [5, 25, 23, 26, 16, 20, 0, 1, 14]
init_pos = np.array([mbt.xstart, mbt.ystart, mbt.zstart])[:, select_balls]

# %%
sample = np.abs(fitsio.read(datafiles[0]))
vmin = 0
vmax = 4

fig, axs = plt.subplots(ncols=1, nrows=1, figsize=(8,4))
im = axs.imshow(sample, vmin=vmin, vmax=vmax, origin='lower', cmap='Greys')
# position for the colorbar
divider = make_axes_locatable(axs)
cax = divider.append_axes('right', size='1%', pad=0.3)
# Adding the colorbar
cbar = plt.colorbar(im, cax = cax)
axs.set_xlim([0, 600])
axs.set_ylim([0, 350])
axs.set_title('Sample image - prepped')

axs.plot(init_pos[0, :], init_pos[1, :], 'ro', ms=4, markerfacecolor='none')
for j, ball in enumerate(select_balls):
    axs.text(init_pos[0, j]+10, init_pos[1, j], str(ball), color='black', fontsize=10, bbox=dict(facecolor='yellow', alpha=0.4, edgecolor='none', pad=1))

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
mbt_dict = {"nt":30,
            "rs":4,
            "am":2,
            "dp":0.3,
            "tdx":1,
            "tdy":100,
            "zdamping":1,
            "ballspacing":15,
            "intsteps":30,
            "mag_thresh":3.5,
            "noise_level":1,
            "track_emergence":False,
            "prep_function":prep_data,
            "datafiles":datafiles,
            "fov":fov,
            "init_pos":init_pos,
            "do_plots":False,
            "astropy":True,
            "verbose":False,
            "outputdir":datadir,
            "fig_dir":PurePath(datadir, 'figures')}

mbt = mblt.MBT(polarity=1, **mbt_dict)
# Out:
# nballs_max = 9

# %%
mbt.track_all_frames()
# Out:
# Tracking with 9 initial balls
# Total number of balls used self.nballs = 9

# %% [markdown]
# Show ball positions & local maxima at the next frame(s)

# %%
plt.close('all')
plt.rcParams.update({'font.size': 8})
ballpos = mbt.ballpos.copy()
ballpos[ballpos == -1] = np.nan
for n in range(0, 1):

    sample = np.abs(fitsio.read(datafiles[n]))
    ymax, xmax = peak_local_max(np.abs(sample), min_distance=2, threshold_abs=3).T
    # Get distances with closest peaks
    distance_matrix = np.sqrt((xmax[:,np.newaxis] - ballpos[0, :, n][np.newaxis,:])**2 + (ymax[:,np.newaxis] - ballpos[1, :, n][np.newaxis,:])**2)
    distance_min = distance_matrix.min(axis=0)
    close_max_inds = distance_matrix.argmin(axis=0)
    close_max = np.array((xmax[close_max_inds], ymax[close_max_inds]))


    fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(1280/dpi, 720/dpi), dpi=dpi)
    axs[0].imshow(sample, vmin=vmin, vmax=vmax, origin='lower', cmap='Greys')
    
    # Plot balls
    axs[0].plot(ballpos[0, :, n], ballpos[1, :, n], 'ro', ms=4, markerfacecolor='none', label='ball position')
    # Plot local max
    axs[0].plot(xmax, ymax, marker='x', ls='none', color='forestgreen', ms=4, label='local max', alpha=0.5)
    
    axs[0].set_xlim([0, 1000])
    axs[0].set_ylim([0, 350])
    axs[0].set_title(f'Local max and tracked positions - Frame {n}')

    axs[1].imshow(sample, vmin=vmin, vmax=vmax, origin='lower', cmap='Greys')
    # Plot balls
    axs[1].plot(ballpos[0, :, n], ballpos[1, :, n], 'ro', ms=4, markerfacecolor='none', label='ball position')
    # Plot local max
    axs[1].plot(close_max[0,:], close_max[1,:], marker='x', ls='none', color='yellow', ms=5, label='local max')

    axs[1].set_xlim([0, 600])
    axs[1].set_ylim([0, 350])
    axs[1].set_title(f'Local max closest to tracked positions')

    plt.tight_layout()
    
    # fig.savefig(PurePath(outputdir, f'Zoom_Balltrack_closest_local_max_L7tum_{n:04d}.jpg'), dpi=dpi) #
    # plt.close()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a = np.zeros([10, 10])
r = np.s_[0:3, 0:4]
a[r]
